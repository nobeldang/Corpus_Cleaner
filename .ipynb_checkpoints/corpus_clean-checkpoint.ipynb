# %% [markdown]
# # Trying_Cleaning_Random_Corpus

# %%
from data_cleaner import tokenized_corpus
data=tokenized_corpus('./kardashian_training')

# %%
print(data)
# Out:
# [['The', 'Kardashian', 'Family', 'Tree', 'Whos', 'Americas', 'famous', 'family'], ['With', 'many', 'baby', 'arrivals', 'relationship', 'dramas', 'getting', 'pretty', 'hard', 'keep', 'Kardashians'], ['By', 'Glamour'], ['Tuesday', 'April'], ['We', 'break', 'Kardashian', 'family', 'tree', 'extensive', 'whos', 'honestly', 'someone'], ['If', 'Kardashians', 'anything', 'omnipresent', 'theyre', 'constantly', 'stealing', 'spotlight', 'social', 'media', 'latest', 'series', 'spinoffs', 'reality', 'show', 'Keeping', 'The', 'Kardashians', 'way', 'FOURTEENTH', 'season'], ['The', 'latest', 'drama', 'hit', 'headlines', 'awkward', 'love', 'triangle', 'Khloe', 'exboyfriend', 'Tristan', 'Thomas', 'Kylies', 'BFF', 'Jordyn', 'Woods'], ['Seriously', 'awksAnd', 'yet', 'youre', 'excused', 'still', 'havent', 'learnt', 'KardashianJenner', 'sister', 'frankly', 'theyre', 'even', 'famous'], ['Believe', 'us', 'youre', 'alone'], ['Where', 'began'], ['Where', 'began'], ['Robert', 'Kardashian'], ['What', 'The', 'la
# ...
